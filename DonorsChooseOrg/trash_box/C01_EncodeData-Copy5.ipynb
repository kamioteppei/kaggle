# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn import metrics
from sklearn.model_selection import cross_validate
from xgboost import XGBClassifier
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
import seaborn as sns

# %%
train_test_df = pd.read_csv("./B02.csv")
train_test_df.info()
# Out:
# /opt/conda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3018: DtypeWarning: Columns (11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260115 entries, 0 to 260114
# Data columns (total 17 columns):
# id                                              260115 non-null object
# teacher_id                                      260115 non-null object
# teacher_prefix                                  260110 non-null object
# school_state                                    260115 non-null object
# project_submitted_datetime                      260115 non-null object
# project_grade_category                          260115 non-null object
# project_subject_categories                      260115 non-null object
# project_subject_subcategories                   260115 non-null object
# project_title                                   260115 non-null object
# project_essay_1                                 260115 non-null object
# project_essay_2                                 260115 non-null object
# project_essay_3                                 9078 non-null object
# project_essay_4                                 9078 non-null object
# project_resource_summary                        260115 non-null object
# teacher_number_of_previously_posted_projects    260115 non-null int64
# project_is_approved                             182080 non-null float64
# total_price                                     260115 non-null float64
# dtypes: float64(2), int64(1), object(14)
# memory usage: 33.7+ MB

# %%
from my_modules.my_encoder import CategoryValueEncoder as CVE
from my_modules.my_encoder import TextValueEncoder as TVE
from my_modules.my_encoder import DateValueEncoder as DVE
from my_modules.my_encoder import NumericValueEncoder as NVE

from sklearn.feature_extraction.text import CountVectorizer
# 出現頻度が1%未満のデータは無視する。
# 理由：1回でた単語のデータのラベルが正であっても負であっても、その単語との因果関係を認められないから。
# We get ValueError when get any data. You should enhance range. 

import nltk
def noun_stem_analyzer(string):
    st = nltk.stem.lancaster.LancasterStemmer()
    return [st.stem(word) for word, pos in nltk.pos_tag(
            nltk.word_tokenize(string)) if pos in ["NNS", "VBP", "VB", "NNP", "JJ"]]

project_resource_summary = train_test_df['project_resource_summary']
enc6 = TVE(project_resource_summary)
enc6.vectorizer = CountVectorizer(min_df=0.01, max_df=1.00, stop_words="english", analyzer=noun_stem_analyzer) 
project_resource_summary = enc6.to_bow_encoding()
# Out:
# MemoryErrorTraceback (most recent call last)
# <ipython-input-7-e8a8ec629b04> in <module>
#      18 enc4 = TVE(project_essay_3)
#      19 enc4.vectorizer = CountVectorizer(min_df=0.00, max_df=1.00, stop_words="english", analyzer=noun_stem_analyzer)
# ---> 20 project_essay_3 = enc4.to_bow_encoding()
#
# /notebooks/kaggle/DonorsChooseOrg/my_modules/my_encoder.py in to_bow_encoding(self)
#      75         bow_encoded = self.vectorizer.fit_transform(corpus)
#      76         #feature_name = self.vectorizer.get_feature_names()
# ---> 77         return self.to_dataframe(bow_encoded.toarray())
#      78
#      79     def to_dataframe(self, encoded):
#
# /opt/conda/lib/python3.6/site-packages/scipy/sparse/compressed.py in toarray(self, order, out)
#     945         if out is None and order is None:
#     946             order = self._swap('cf')[0]
# --> 947         out = self._process_toarray_args(order, out)
#     948         if not (out.flags.c_contiguous or out.flags.f_contiguous):
#     949             raise ValueError('Output array must be C or F contiguous')
#
# /opt/conda/lib/python3.6/site-packages/scipy/sparse/base.py in _process_toarray_args(self, order, out)
#    1182             return out
#    1183         else:
# -> 1184             return np.zeros(self.shape, dtype=self.dtype, order=order)
#    1185
#    1186
#
# MemoryError:

# %%
project_essay_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 